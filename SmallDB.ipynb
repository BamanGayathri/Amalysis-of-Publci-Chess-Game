# %%
# Install necessary library for handling PGN files
# !pip install python-chess

import os
from google.colab import files
import chess.pgn

# Upload the .pgn file
uploaded = '/content/dataset.pgn'

# Assuming the file name is dataset.pgn, adapt if the name is different
file_name = uploaded

# Function to split PGN file into smaller parts
def split_pgn(file_path, output_dir, games_per_file):
    """
    Splits a PGN file into smaller files with a fixed number of games.

    Parameters:
        file_path (str): Path to the input PGN file.
        output_dir (str): Directory to save the output files.
        games_per_file (int): Number of games per smaller file.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    with open(file_path, "r") as file:
        game_count = 0
        part_number = 1
        output_file = open(os.path.join(output_dir, f"part_{part_number}.pgn"), "w")

        while True:
            game = chess.pgn.read_game(file)
            if game is None:  # End of file
                break

            output_file.write(str(game) + "\n\n")
            game_count += 1

            if game_count >= games_per_file:
                output_file.close()
                part_number += 1
                game_count = 0
                output_file = open(os.path.join(output_dir, f"part_{part_number}.pgn"), "w")

        output_file.close()
    print(f"Splitting completed. Files saved in {output_dir}")

# Define parameters
output_directory = "merge_files_pgn"
games_per_part = 1000  # Adjust based on desired number of games per file

# Split the dataset
split_pgn(file_name, output_directory, games_per_part)

# Zip the output directory for easy download
# !zip -r merge_files_pgn.zip merge_files_pgn

# Download the zip file
files.download("merge_files_pgn.zip")
# Out:
# Collecting python-chess
#   Downloading python_chess-1.999-py3-none-any.whl.metadata (776 bytes)
# Collecting chess<2,>=1 (from python-chess)
#   Downloading chess-1.11.1.tar.gz (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Downloading python_chess-1.999-py3-none-any.whl (1.4 kB)
# Building wheels for collected packages: chess
#   Building wheel for chess (setup.py) ... done
#   Created wheel for chess: filename=chess-1.11.1-py3-none-any.whl size=148497 sha256=68dda417159c789eae5215b13b3a4843767f11068cfd1f389f5f1e48aabc613e
#   Stored in directory: /root/.cache/pip/wheels/2e/2d/23/1bfc95db984ed3ecbf6764167dc7526d0ab521cf9a9852544e
# Successfully built chess
# Installing collected packages: chess, python-chess
# Successfully installed chess-1.11.1 python-chess-1.999
# Splitting completed. Files saved in merge_files_pgn
#   adding: merge_files_pgn/ (stored 0%)
#   adding: merge_files_pgn/part_98.pgn (deflated 73%)
#   adding: merge_files_pgn/part_104.pgn (deflated 72%)
#   adding: merge_files_pgn/part_62.pgn (deflated 73%)
#   adding: merge_files_pgn/part_15.pgn (deflated 72%)
#   adding: merge_files_pgn/part_73.pgn (deflated 73%)
#   adding: merge_files_pgn/part_13.pgn (deflated 73%)
#   adding: merge_files_pgn/part_107.pgn (deflated 72%)
#   adding: merge_files_pgn/part_6.pgn (deflated 72%)
#   adding: merge_files_pgn/part_45.pgn (deflated 72%)
#   adding: merge_files_pgn/part_22.pgn (deflated 72%)
#   adding: merge_files_pgn/part_53.pgn (deflated 72%)
#   adding: merge_files_pgn/part_26.pgn (deflated 73%)
#   adding: merge_files_pgn/part_88.pgn (deflated 72%)
#   adding: merge_files_pgn/part_18.pgn (deflated 72%)
#   adding: merge_files_pgn/part_38.pgn (deflated 72%)
#   adding: merge_files_pgn/part_93.pgn (deflated 73%)
#   adding: merge_files_pgn/part_8.pgn (deflated 73%)
#   adding: merge_files_pgn/part_111.pgn (deflated 72%)
#   adding: merge_files_pgn/part_17.pgn (deflated 72%)
#   adding: merge_files_pgn/part_105.pgn (deflated 72%)
#   adding: merge_files_pgn/part_37.pgn (deflated 72%)
#   adding: merge_files_pgn/part_11.pgn (deflated 72%)
#   adding: merge_files_pgn/part_24.pgn (deflated 72%)
#   adding: merge_files_pgn/part_12.pgn (deflated 73%)
#   adding: merge_files_pgn/part_28.pgn (deflated 73%)
#   adding: merge_files_pgn/part_23.pgn (deflated 72%)
#   adding: merge_files_pgn/part_20.pgn (deflated 72%)
#   adding: merge_files_pgn/part_21.pgn (deflated 72%)
#   adding: merge_files_pgn/part_51.pgn (deflated 72%)
#   adding: merge_files_pgn/part_121.pgn (deflated 72%)
#   adding: merge_files_pgn/part_34.pgn (deflated 72%)
#   adding: merge_files_pgn/part_59.pgn (deflated 72%)
#   adding: merge_files_pgn/part_42.pgn (deflated 72%)
#   adding: merge_files_pgn/part_27.pgn (deflated 72%)
#   adding: merge_files_pgn/part_35.pgn (deflated 72%)
#   adding: merge_files_pgn/part_40.pgn (deflated 73%)
#   adding: merge_files_pgn/part_99.pgn (deflated 72%)
#   adding: merge_files_pgn/part_46.pgn (deflated 72%)
#   adding: merge_files_pgn/part_97.pgn (deflated 72%)
#   adding: merge_files_pgn/part_116.pgn (deflated 72%)
#   adding: merge_files_pgn/part_96.pgn (deflated 72%)
#   adding: merge_files_pgn/part_72.pgn (deflated 72%)
#   adding: merge_files_pgn/part_9.pgn (deflated 73%)
#   adding: merge_files_pgn/part_91.pgn (deflated 72%)
#   adding: merge_files_pgn/part_109.pgn (deflated 73%)
#   adding: merge_files_pgn/part_84.pgn (deflated 72%)
#   adding: merge_files_pgn/part_65.pgn (deflated 72%)
#   adding: merge_files_pgn/part_110.pgn (deflated 73%)
#   adding: merge_files_pgn/part_86.pgn (deflated 73%)
#   adding: merge_files_pgn/part_30.pgn (deflated 72%)
#   adding: merge_files_pgn/part_108.pgn (deflated 72%)
#   adding: merge_files_pgn/part_113.pgn (deflated 72%)
#   adding: merge_files_pgn/part_85.pgn (deflated 72%)
#   adding: merge_files_pgn/part_71.pgn (deflated 72%)
#   adding: merge_files_pgn/part_101.pgn (deflated 72%)
#   adding: merge_files_pgn/part_14.pgn (deflated 72%)
#   adding: merge_files_pgn/part_64.pgn (deflated 72%)
#   adding: merge_files_pgn/part_57.pgn (deflated 72%)
#   adding: merge_files_pgn/part_66.pgn (deflated 73%)
#   adding: merge_files_pgn/part_52.pgn (deflated 73%)
#   adding: merge_files_pgn/part_63.pgn (deflated 72%)
#   adding: merge_files_pgn/part_2.pgn (deflated 72%)
#   adding: merge_files_pgn/part_19.pgn (deflated 72%)
#   adding: merge_files_pgn/part_78.pgn (deflated 73%)
#   adding: merge_files_pgn/part_49.pgn (deflated 72%)
#   adding: merge_files_pgn/part_80.pgn (deflated 72%)
#   adding: merge_files_pgn/part_79.pgn (deflated 72%)
#   adding: merge_files_pgn/part_56.pgn (deflated 73%)
#   adding: merge_files_pgn/part_92.pgn (deflated 72%)
#   adding: merge_files_pgn/part_60.pgn (deflated 72%)
#   adding: merge_files_pgn/part_120.pgn (deflated 72%)
#   adding: merge_files_pgn/part_100.pgn (deflated 72%)
#   adding: merge_files_pgn/part_87.pgn (deflated 72%)
#   adding: merge_files_pgn/part_106.pgn (deflated 73%)
#   adding: merge_files_pgn/part_94.pgn (deflated 73%)
#   adding: merge_files_pgn/part_5.pgn (deflated 72%)
#   adding: merge_files_pgn/part_1.pgn (deflated 74%)
#   adding: merge_files_pgn/part_119.pgn (deflated 72%)
#   adding: merge_files_pgn/part_67.pgn (deflated 72%)
#   adding: merge_files_pgn/part_76.pgn (deflated 72%)
#   adding: merge_files_pgn/part_114.pgn (deflated 73%)
#   adding: merge_files_pgn/part_39.pgn (deflated 72%)
#   adding: merge_files_pgn/part_16.pgn (deflated 73%)
#   adding: merge_files_pgn/part_68.pgn (deflated 72%)
#   adding: merge_files_pgn/part_74.pgn (deflated 73%)
#   adding: merge_files_pgn/part_69.pgn (deflated 73%)
#   adding: merge_files_pgn/part_29.pgn (deflated 73%)
#   adding: merge_files_pgn/part_115.pgn (deflated 72%)
#   adding: merge_files_pgn/part_118.pgn (deflated 73%)
#   adding: merge_files_pgn/part_122.pgn (deflated 72%)
#   adding: merge_files_pgn/part_103.pgn (deflated 72%)
#   adding: merge_files_pgn/part_117.pgn (deflated 72%)
#   adding: merge_files_pgn/part_25.pgn (deflated 72%)
#   adding: merge_files_pgn/part_81.pgn (deflated 72%)
#   adding: merge_files_pgn/part_4.pgn (deflated 73%)
#   adding: merge_files_pgn/part_54.pgn (deflated 72%)
#   adding: merge_files_pgn/part_58.pgn (deflated 72%)
#   adding: merge_files_pgn/part_48.pgn (deflated 73%)
#   adding: merge_files_pgn/part_90.pgn (deflated 73%)
#   adding: merge_files_pgn/part_77.pgn (deflated 72%)
#   adding: merge_files_pgn/part_43.pgn (deflated 73%)
#   adding: merge_files_pgn/part_3.pgn (deflated 72%)
#   adding: merge_files_pgn/part_83.pgn (deflated 72%)
#   adding: merge_files_pgn/part_112.pgn (deflated 72%)
#   adding: merge_files_pgn/part_55.pgn (deflated 73%)
#   adding: merge_files_pgn/part_31.pgn (deflated 72%)
#   adding: merge_files_pgn/part_36.pgn (deflated 73%)
#   adding: merge_files_pgn/part_44.pgn (deflated 73%)
#   adding: merge_files_pgn/part_33.pgn (deflated 73%)
#   adding: merge_files_pgn/part_89.pgn (deflated 73%)
#   adding: merge_files_pgn/part_10.pgn (deflated 72%)
#   adding: merge_files_pgn/part_32.pgn (deflated 73%)
#   adding: merge_files_pgn/part_50.pgn (deflated 72%)
#   adding: merge_files_pgn/part_70.pgn (deflated 73%)
#   adding: merge_files_pgn/part_102.pgn (deflated 73%)
#   adding: merge_files_pgn/part_61.pgn (deflated 72%)
#   adding: merge_files_pgn/part_41.pgn (deflated 72%)
#   adding: merge_files_pgn/part_82.pgn (deflated 73%)
#   adding: merge_files_pgn/part_47.pgn (deflated 73%)
#   adding: merge_files_pgn/part_95.pgn (deflated 72%)
#   adding: merge_files_pgn/part_75.pgn (deflated 72%)
#   adding: merge_files_pgn/part_7.pgn (deflated 72%)
